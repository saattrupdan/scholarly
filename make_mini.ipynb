# %%
import pandas as pd

# %%
df = pd.read_csv('data/arxiv_data_mcats_pp.tsv', sep = '\t')

# %%
mini_df = df.sample(10000)

# %%
mini_df.to_csv('data/arxiv_data_mcats_pp_mini.tsv', sep = '\t', index = False)
